# %% [markdown]
# ## Understanding India's Irrigation Potential

# %% [markdown]
# ##  Introduction:
#
# >Since the beginning of crop cultivation, irrigation has been used to compensate for the lack of precipitation. In rice cultivation, irrigation also controls the water level in the fields and suppresses weed growth. Crop yields are higher
# and the risk of crop failures is lower in irrigated agriculture. Because the risk of drought stress is lower on irrigated land,
# farmers are more likely to spend on other inputs like fertilizers. Irrigation may also increase cropping intensity, allowing farmers to cultivate several crops per year on the same field. It is important, therefore, when assessing crop
# productivity and food security, to consider the availability of irrigation infrastructure.
#
# ### Irrigation in Asia
# __[source code](https://anaconda.org/haripriya_t_v/preliminary_code)__
# ![image.png](attachment:image.png)
#
# >Total area equipped for irrigation in Asia is 46 million hectares (ha) and 64.5 million hectares (ha) are actually under irrigation. Southern and Eastern regions of Asia have irrigation on areas that are not even equipped for irrigation. This can have a great negative impact on the environment and however a positive impact on each country's GDP per capita. Analysis about these impacts upon India can be found __[here]()__.
#
# __[source code](https://anaconda.org/haripriya_t_v/preliminary_code)__
# ![asia%20choromap.png](attachment:asia%20choromap.png)
#
# > The map shows the countries with the largest amount of irrigation potentials are India (139.5k ha) and China (70k ha). **Thus India is the country with the highest irrigation potential in Asia.**

# %% [markdown]
# ### India's Irrigation Potential
#
# >The area which can potentially be irrigated depends on the physical resources 'soil' and 'water', combined with the irrigation water requirements as determined by the cropping patterns and climate. However, environmental and socioeconomic constraints also have to be taken into consideration in order to guarantee a sustainable use of the available physical resources.
#
# > In the __[further part](https://anaconda.org/haripriya_t_v/eda_code)__ of the report,
# > - the land area and water resources in India are summarized
# > - the land and water requirements for irrigation in India are assessed
# > - existing information on irrigation and its potential in India are explored and
# > - impact of irrigation on India's environment and economy are discusssed.
